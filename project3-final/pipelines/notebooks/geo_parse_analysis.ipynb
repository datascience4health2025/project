# %%
# importing libraries
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd 
import GEOparse
import plotly.graph_objects as go

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# ### To-do List
#
# * Entrega Parcial
#     * Construir df final (ok)
#     * Diferenciar e agrupar pacientes leves e medios/graves pelo sledai (ok)
#     * Analise de expressao diferencial
#     * Montar a rede de expressão diferencial e analisar
#
# * Neutrofilos -> Velocidade da resposta imune (reduz vies da analise do médico)
#     * -> Encontrar genes mais responsáveis pelo aumento no perecentual de neutrofilos
#     * -> Selecionar os genes mais relevantes para o aumento dos neutrofilos
#     * -> Correlação entre nivel de expressao genica e resposta imune

# %%
import GEOparse
import pandas as pd
import numpy as np

class GEOParser:
    """
    Parser for GEO datasets using GEOparse.
    First version specific for GSE121239 (Lúpus).

    Parameters
    -----------
    geo_id : str
        GEO Series ID (e.g., 'GSE121239').
    destdir : str
        Directory to download GEO data.
    gene_id_cols : list of str, optional
        Columns to use for gene ID mapping. Default is ['ID', 'Gene Symbol', 'Gene Title'].
    meta_map : dict, optional
        Mapping of metadata fields to their index in characteristics_ch1. 
    """
    def __init__(self, geo_id, destdir, gene_id_cols=None, meta_map=None):
        self.geo_id = geo_id
        self.destdir = destdir
        self.gene_id_cols = gene_id_cols or ['ID', 'Gene Symbol', 'Gene Title']
        self.meta_map = meta_map
        self.gse = None
        self.gpl = None

    def load(self):
        """
        Load GEO Series data.
        """
        self.gse = GEOparse.get_GEO(geo=self.geo_id, destdir=self.destdir, silent=True)

    def try_cast(self, val, typ):
        """
        Try to cast a value to a specified type, return NaN on failure.

        Parameters
        ----------
        val : any
            Value to cast.
        typ : type
            Target type for casting.
        """
        try:
            return typ(val)
        except (ValueError, TypeError):
            return np.nan

    def select_main_gene(self, gene_str, separator='///'):
        """
        Select the main gene from a string of gene symbols separated by a given separator.
        Parameters
        ----------
        gene_str : str
            String containing gene symbols separated by the specified separator.
        separator : str, optional
            Separator used in the gene string. Default is '///'.
        Returns
        -------
        main_gene : str or np.nan
            The selected main gene symbol, or NaN if input is NaN.
        """
        if pd.isna(gene_str):
            return np.nan
        # Lista de genes encontrados
        genes = [g.strip() for g in gene_str.split(separator)]

        # Prioriza genes que não começam com LOC (Locus genômico)
        known_genes = [g for g in genes if not g.startswith('LOC')]
        if known_genes:
            return known_genes[0]
        return genes[0]  # Se só tem LOC, retorna o primeiro

    def parse(self):
        """
        Parse the loaded GEO Series data.

        Returns
        -------
        gene_data: pd.DataFrame
            Dataframe with Gene expression data.
        patient_data: pd.DataFrame
            Dataframe with Patient metadata.
        """
        if self.gse is None:
            self.load()

        # 1. Cria listas com metadados e expressao dos paciente e expressao genica 
        patient_meta_list = []
        gene_data_list = []

        # 2. Itera sobre os GSMs para extrair metadados e dados de expressão
        for gsm_name, gsm in self.gse.gsms.items():

            # 2.1. Extrai metadados do paciente
            meta = gsm.metadata['characteristics_ch1']
            patient_meta = {'sample_code': gsm_name}

            # 2.2. Parse de metadados de acordo com o mapeamento fornecido
            for key, idx in self.meta_map.items():
                # 2.3 . Extrai valor da lista de metadados e faz cast apropriado
                val = meta[idx].split(':')[1].strip() if len(meta) > idx else None
                if key == 'sledai':
                    val = self.try_cast(val, int)
                elif key == 'visit_date':
                    val = self.try_cast(val, pd.Timestamp)
                elif key == 'neutrophil_percent':
                    val = self.try_cast(val, float)
                # 2.4. Adiciona informação ao dicionario de metadados do paciente
                patient_meta[key] = val
            
            patient_meta_list.append(patient_meta)

            # 2.5. Extrai dados de expressão gênica
            gene_df = gsm.table[['ID_REF', 'VALUE']].copy()
            gene_df['sample_code'] = gsm_name
            gene_data_list.append(gene_df)

        # 3. Concatena dados de expressão gênica em um único DataFrame
        gene_data = pd.concat(gene_data_list, ignore_index=True)

        # 4. GPLS: plataforma com anotação de genes, incluindo nome e símbolo
        self.gpl = self.gse.gpls[list(self.gse.gpls.keys())[0]].table

        # 5. Recupera nome e título do gene com base no ID
        gene_data = gene_data.merge(self.gpl[self.gene_id_cols], left_on='ID_REF', right_on='ID', how='left')
        gene_data = gene_data.rename(columns={'VALUE': 'gene_expression_value', 'Gene Symbol': 'gene_symbol', 'Gene Title': 'gene_title'})
        gene_data = gene_data[['sample_code', 'ID', 'gene_symbol', 'gene_title', 'gene_expression_value']]

        # 6. Metadados do paciente em dataframe
        patient_data = pd.DataFrame(patient_meta_list)
        patient_data['patient_id'] = patient_data['patient_id'].replace({'NA': np.nan})
        patient_data = patient_data.sort_values(by=['patient_id', 'visit_date'])

        return gene_data, patient_data

# %% [markdown]
# ## Loading Data

# %%
meta_map = {
    'state': 0,
    'patient_id': 1,
    'sledai': 2,
    'visit_date': 3,
    'neutrophil_percent': 5
}

# Cria objeto parser
parser = GEOParser(geo_id="GSE121239", destdir="../../data/raw/", meta_map=meta_map)

# Parse dos dados e armazena em tabelas
gene_data, patient_data = parser.parse()

# Mantem o "gene principal" em casos de genes separados por '///'
gene_data['main_gene'] = gene_data['gene_symbol'].apply(parser.select_main_gene)

# Remove valores de microarray (Affymetrix) -> Controle de qualidade de experimento
gene_data = gene_data[~gene_data['ID'].str.startswith('AFFX')]
# Out:
# /home/cs331285/anaconda3/envs/ml/lib/python3.13/site-packages/GEOparse/GEOparse.py:401: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   return read_csv(StringIO(data), index_col=None, sep="\t")

# %%
patient_data.head()
# Out:
#     sample_code                         state patient_id  sledai visit_date  \
# 105  GSM3428415  Systemic Lupus Erythematosus       1001       4 2009-10-08
# 106  GSM3428416  Systemic Lupus Erythematosus       1001       2 2010-01-11
# 107  GSM3428417  Systemic Lupus Erythematosus       1001       6 2010-03-29
# 108  GSM3428418  Systemic Lupus Erythematosus       1041       2 2009-09-24
# 109  GSM3428419  Systemic Lupus Erythematosus       1041      10 2009-12-10
#
#      neutrophil_percent
# 105                65.2
# 106                61.5
# 107                57.5
# 108                73.8
# 109                64.1

# %%
gene_data.head()
# Out:
#   sample_code            ID gene_symbol  \
# 0  GSM3428310  1007_PM_s_at        DDR1
# 1  GSM3428310    1053_PM_at        RFC2
# 2  GSM3428310     117_PM_at       HSPA6
# 3  GSM3428310     121_PM_at        PAX8
# 4  GSM3428310  1255_PM_g_at      GUCA1A
#
#                                     gene_title  gene_expression_value  \
# 0  discoidin domain receptor tyrosine kinase 1               4.955257
# 1  replication factor C (activator 1) 2, 40kDa               5.984784
# 2         heat shock 70kDa protein 6 (HSP70B')               9.477945
# 3                                 paired box 8               4.553229
# 4      guanylate cyclase activator 1A (retina)               1.921190
#
#   main_gene
# 0      DDR1
# 1      RFC2
# 2     HSPA6
# 3      PAX8
# 4    GUCA1A

# %% [markdown]
# ### Classificando lesões

# %%
def classify_lesion(sledai_score):
    if sledai_score == 0:
        return 'healthy'
    if 1 <= sledai_score <= 6:
        return 'leve'
    elif 7 <= sledai_score <= 11:
        return 'media'
    else:
        return 'grave'

# %%
patient_data['class'] = patient_data['sledai'].apply(classify_lesion)
patient_data['class_group'] = np.where(patient_data['class'].isin(['grave', 'media']), 'medio/grave', 'leve')
patient_data['class_group'] = np.where(patient_data['class'] == 'healthy', 'healthy', patient_data['class_group'])

# %%
patient_data.head()
# Out:
#     sample_code                         state patient_id  sledai visit_date  \
# 105  GSM3428415  Systemic Lupus Erythematosus       1001       4 2009-10-08
# 106  GSM3428416  Systemic Lupus Erythematosus       1001       2 2010-01-11
# 107  GSM3428417  Systemic Lupus Erythematosus       1001       6 2010-03-29
# 108  GSM3428418  Systemic Lupus Erythematosus       1041       2 2009-09-24
# 109  GSM3428419  Systemic Lupus Erythematosus       1041      10 2009-12-10
#
#      neutrophil_percent  class  class_group
# 105                65.2   leve         leve
# 106                61.5   leve         leve
# 107                57.5   leve         leve
# 108                73.8   leve         leve
# 109                64.1  media  medio/grave

# %%
gene_data.to_parquet('../../data/processed/gene_data.parquet', index=False)
patient_data.to_csv('../../data/processed/patient_data.csv', index=False)

# %%
patient_data
# Out:
#     sample_code                         state patient_id  sledai visit_date  \
# 105  GSM3428415  Systemic Lupus Erythematosus       1001       4 2009-10-08
# 106  GSM3428416  Systemic Lupus Erythematosus       1001       2 2010-01-11
# 107  GSM3428417  Systemic Lupus Erythematosus       1001       6 2010-03-29
# 108  GSM3428418  Systemic Lupus Erythematosus       1041       2 2009-09-24
# 109  GSM3428419  Systemic Lupus Erythematosus       1041      10 2009-12-10
# ..          ...                           ...        ...     ...        ...
# 15   GSM3428325                       Healthy        NaN       0        NaT
# 16   GSM3428326                       Healthy        NaN       0        NaT
# 17   GSM3428327                       Healthy        NaN       0        NaT
# 18   GSM3428328                       Healthy        NaN       0        NaT
# 19   GSM3428329                       Healthy        NaN       0        NaT
#
#      neutrophil_percent    class  class_group
# 105                65.2     leve         leve
# 106                61.5     leve         leve
# 107                57.5     leve         leve
# 108                73.8     leve         leve
# 109                64.1    media  medio/grave
# ..                  ...      ...          ...
# 15                  NaN  healthy      healthy
# 16                  NaN  healthy      healthy
# 17                  NaN  healthy      healthy
# 18                  NaN  healthy      healthy
# 19                  NaN  healthy      healthy
#
# [312 rows x 8 columns]

# %%
def plot_pie_distribution(patient_data, col='class'):
    if col == 'class':
        colors = ["#ABACB2", "#bb77ba", "#39b3c2", "#7e7ae7"]
    else:
        colors = ["#39b3c2", "#7e7ae7"]
        
    fig = go.Figure(data=[go.Pie(
        labels=[label.capitalize() for label in np.sort(patient_data[col].unique())],
        values=patient_data[col].value_counts(normalize=True).sort_index().values,
        hole=0.34,
        marker_colors=colors,
        textinfo='percent+label',
        insidetextorientation='radial',
        textfont=dict(family='Arial Black')
    )])
    
    fig.update_layout(
        title=dict(x=0.5, text='Distribuição do Grau de Lesão (SLEDAI) nos Pacientes'),
        template='plotly_white',
        showlegend=False,
        width=500
    )
    
    fig.show()

fig = plot_pie_distribution(patient_data, col='class')
fig = plot_pie_distribution(patient_data.query("class_group != 'healthy'"), col='class_group')

# %%
# Filtra a observação com maior SLEDAI por paciente
patient_data['max_sledai'] = patient_data.groupby('patient_id')['sledai'].transform('max')
patient_data_max_sledai = patient_data.query("sledai == max_sledai").drop(columns=['max_sledai'])

# %%
df = gene_data.merge(patient_data_max_sledai, on='sample_code')
# df = df[['sample_code', 'patient_id', 'state', 'sledai', 'visit_date', 'neutrophil_percent', 'gene_symbol', 'gene_title', 'gene_expression_value', 'ID_REF']]

# %%
import scipy.stats as stats

# Supondo que df tem colunas: 'gene_symbol', 'gene_expression_value', 'class'
# Exemplo: comparar 'leve' vs 'grave'

genes = df['main_gene'].dropna().unique()
results = []

for gene in genes:
    group1 = df[(df['main_gene'] == gene) & (df['class_group'] == 'leve')]['gene_expression_value']
    group2 = df[(df['main_gene'] == gene) & (df['class_group'] == 'medio/grave')]['gene_expression_value']
    stat, pval = stats.ttest_ind(group1, group2, equal_var=False)
    results.append({'gene': gene, 'pval': pval, 'mean_leve': group1.mean(), 'mean_grave': group2.mean()})
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 10
#       7 results = []
#       9 for gene in genes:
# ---> 10     group1 = df[(df['main_gene'] == gene) & (df['class_group'] == 'leve')]['gene_expression_value']
#      11     group2 = df[(df['main_gene'] == gene) & (df['class_group'] == 'medio/grave')]['gene_expression_value']
#      12     stat, pval = stats.ttest_ind(group1, group2, equal_var=False)
#
# File ~/anaconda3/envs/ml/lib/python3.13/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/anaconda3/envs/ml/lib/python3.13/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File ~/anaconda3/envs/ml/lib/python3.13/site-packages/pandas/core/series.py:6138, in Series._cmp_method(self, other, op)
#    6135 lvalues = self._values
#    6136 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6138 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6140 return self._construct_result(res_values, name=res_name)
#
# File ~/anaconda3/envs/ml/lib/python3.13/site-packages/pandas/core/ops/array_ops.py:344, in comparison_op(left, right, op)
#     341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
#     347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~/anaconda3/envs/ml/lib/python3.13/site-packages/pandas/core/ops/array_ops.py:129, in comp_method_OBJECT_ARRAY(op, x, y)
#     127     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     128 else:
# --> 129     result = libops.scalar_compare(x.ravel(), y, op)
#     130 return result.reshape(x.shape)
#
# KeyboardInterrupt:

# %%
# DataFrame com resultados
res_df = pd.DataFrame(results)
res_df['log2fc'] = np.log2(res_df['mean_grave'] + 1) - np.log2(res_df['mean_leve'] + 1)
res_df = res_df.sort_values('pval')

# Genes mais diferenciais
top_genes = res_df[res_df['pval'] < 0.05].sort_values('log2fc', ascending=False)

# %%
results
# Out:
# [{'gene': 'DDR1',
#   'pval': np.float64(0.2100797001084677),
#   'mean_leve': np.float64(4.425244505479166),
#   'mean_grave': np.float64(4.369157444695312)},
#  {'gene': 'RFC2',
#   'pval': np.float64(0.20727321476765737),
#   'mean_leve': np.float64(6.259382690402777),
#   'mean_grave': np.float64(6.191040201328125)},
#  {'gene': 'HSPA6',
#   'pval': np.float64(0.9562692446052213),
#   'mean_leve': np.float64(9.587159257618055),
#   'mean_grave': np.float64(9.582517183390625)},
#  {'gene': 'PAX8',
#   'pval': np.float64(0.9477600426952131),
#   'mean_leve': np.float64(3.476633524646701),
#   'mean_grave': np.float64(3.4725149381523437)},
#  {'gene': 'GUCA1A',
#   'pval': np.float64(0.8995143302419972),
#   'mean_leve': np.float64(3.27648892130787),
#   'mean_grave': np.float64(3.2895532785624995)},
#  {'gene': 'UBA7',
#   'pval': np.float64(0.027651728205105915),
#   'mean_leve': np.float64(7.942164412815973),
#   'mean_grave': np.float64(7.825528932)},
#  {'gene': 'THRA',
#   'pval': np.float64(0.9894981719394134),
#   'mean_leve': np.float64(4.843992193317708),
#   'mean_grave': np.float64(4.844992044609375)},
#  {'gene': 'PTPN21',
#   'pval': np.float64(0.9269691282758964),
#   'mean_leve': np.float64(2.9486750925736107),
#   'mean_grave': np.float64(2.95615143126875)},
#  {'gene': 'CCL5',
#   'pval': np.float64(0.9185564549795817),
#   'mean_leve': np.float64(8.86170368886111),
#   'mean_grave': np.float64(8.851775397979166)},
#  {'gene': 'CYP2E1',
#   'pval': np.float64(0.8166954106986392),
#   'mean_leve': np.float64(3.5301438635572917),
#   'mean_grave': np.float64(3.5112960784140625)},
#  {'gene': 'EPHB3',
#   'pval': np.float64(0.9423019184379623),
#   'mean_leve': np.float64(4.372970666454861),
#   'mean_grave': np.float64(4.383114266625)},
#  {'gene': 'ESRRA',
#   'pval': np.float64(0.5667974747105806),
#   'mean_leve': np.float64(5.81350716771875),
#   'mean_grave': np.float64(5.768896700359375)},
#  {'gene': 'CYP2A6',
#   'pval': np.float64(0.7127334378281333),
#   'mean_leve': np.float64(3.50590681528125),
#   'mean_grave': np.float64(3.5265691974140623)},
#  {'gene': 'SCARB1',
#   'pval': np.float64(0.40141698835486805),
#   'mean_leve': np.float64(3.779313699769097),
#   'mean_grave': np.float64(3.828603049703125)},
#  {'gene': 'TTLL12',
#   'pval': np.float64(0.06577243177583803),
#   'mean_leve': np.float64(6.577981674958333),
#   'mean_grave': np.float64(6.481751999546875)},
#  {'gene': 'NCRNA00152',
#   'pval': np.float64(0.17736400047135262),
#   'mean_leve': np.float64(5.1813174451875),
#   'mean_grave': np.float64(5.04211678709375)},
#  {'gene': 'WFDC2',
#   'pval': np.float64(0.9490725041347027),
#   'mean_leve': np.float64(4.023718000233796),
#   'mean_grave': np.float64(4.0277645161562505)},
#  {'gene': 'MAPK1',
#   'pval': np.float64(0.829876377317297),
#   'mean_leve': np.float64(7.220351087847222),
#   'mean_grave': np.float64(7.1975782686205365)},
#  {'gene': 'ADAM32',
#   'pval': np.float64(0.29531787861113773),
#   'mean_leve': np.float64(2.7517382842499996),
#   'mean_grave': np.float64(2.8108132890000004)},
#  {'gene': 'SPATA17',
#   'pval': np.float64(0.6650762529005492),
#   'mean_leve': np.float64(1.8808886966111114),
#   'mean_grave': np.float64(1.9045919819687498)},
#  {'gene': 'PRR22',
#   'pval': np.float64(0.7688571504812888),
#   'mean_leve': np.float64(4.132249850833333),
#   'mean_grave': np.float64(4.160537322031249)},
#  {'gene': 'PXK',
#   'pval': np.float64(0.9085806610403755),
#   'mean_leve': np.float64(5.905887383518518),
#   'mean_grave': np.float64(5.893004812458334)},
#  {'gene': 'VPS18',
#   'pval': np.float64(0.7572325735113566),
#   'mean_leve': np.float64(4.863292538052083),
#   'mean_grave': np.float64(4.920251463406251)},
#  {'gene': 'C9orf30',
#   'pval': np.float64(0.3373326442383505),
#   'mean_leve': np.float64(6.3774254423020835),
#   'mean_grave': np.float64(6.128499743171875)},
#  {'gene': 'SLC46A1',
#   'pval': np.float64(0.8435688069234317),
#   'mean_leve': np.float64(3.446652223668403),
#   'mean_grave': np.float64(3.4608826533203123)},
#  {'gene': 'TIMD4',
#   'pval': np.float64(0.6942945003270335),
#   'mean_leve': np.float64(3.203758291125),
#   'mean_grave': np.float64(3.2408571683125)},
#  {'gene': 'SLC39A5',
#   'pval': np.float64(0.5004846814692866),
#   'mean_leve': np.float64(4.379377232972222),
#   'mean_grave': np.float64(4.41331723703125)},
#  {'gene': 'ZDHHC11',
#   'pval': np.float64(0.7124160605052827),
#   'mean_leve': np.float64(4.87848725036111),
#   'mean_grave': np.float64(4.928120550770833)},
#  {'gene': 'ATP6V1E2',
#   'pval': np.float64(0.3841355584287157),
#   'mean_leve': np.float64(5.804001394979166),
#   'mean_grave': np.float64(5.74132397246875)},
#  {'gene': 'AFG3L1',
#   'pval': np.float64(0.5440014273356237),
#   'mean_leve': np.float64(5.235680045319445),
#   'mean_grave': np.float64(5.184569603447916)},
#  {'gene': 'CILP2',
#   'pval': np.float64(0.43366452608432593),
#   'mean_leve': np.float64(3.442805505770833),
#   'mean_grave': np.float64(3.53321888378125)},
#  {'gene': 'PIGX',
#   'pval': np.float64(0.7646281261980106),
#   'mean_leve': np.float64(6.695964870138888),
#   'mean_grave': np.float64(6.723067920187501)},
#  {'gene': 'TMEM196',
#   'pval': np.float64(0.6948106547084509),
#   'mean_leve': np.float64(1.9986814075902777),
#   'mean_grave': np.float64(1.96777766153125)},
#  {'gene': 'SLC39A13',
#   'pval': np.float64(0.6860159792706966),
#   'mean_leve': np.float64(5.447710741791667),
#   'mean_grave': np.float64(5.38533620403125)},
#  {'gene': 'BEST4',
#   'pval': np.float64(0.6497609562895582),
#   'mean_leve': np.float64(3.682348932861111),
#   'mean_grave': np.float64(3.65176512925)},
#  {'gene': 'AKD1',
#   'pval': np.float64(0.8083552491000551),
#   'mean_leve': np.float64(4.429808533627315),
#   'mean_grave': np.float64(4.4001703119375)},
#  {'gene': 'CORO6',
#   'pval': np.float64(0.43453521365778947),
#   'mean_leve': np.float64(3.3213862406180557),
#   'mean_grave': np.float64(3.3867495742812497)},
#  {'gene': 'TMEM106A',
#   'pval': np.float64(0.899560391875013),
#   'mean_leve': np.float64(4.470841683508681),
#   'mean_grave': np.float64(4.4557740650468745)},
#  {'gene': 'ALG10',
#   'pval': np.float64(0.47553461258919405),
#   'mean_leve': np.float64(2.943993335013889),
#   'mean_grave': np.float64(3.010002432265625)},
#  {'gene': 'TTC39C',
#   'pval': np.float64(0.8679163163538434),
#   'mean_leve': np.float64(6.8174505917430555),
#   'mean_grave': np.float64(6.7889747008375)},
#  {'gene': 'NEXN',
#   'pval': np.float64(0.38814735847976933),
#   'mean_leve': np.float64(6.333273162545138),
#   'mean_grave': np.float64(6.207026367921875)},
#  {'gene': 'C15orf40',
#   'pval': np.float64(0.34126604052969034),
#   'mean_leve': np.float64(4.953533331395834),
#   'mean_grave': np.float64(4.8198577879687505)},
#  {'gene': 'RAX2',
#   'pval': np.float64(0.9873548594925986),
#   'mean_leve': np.float64(6.038674044243056),
#   'mean_grave': np.float64(6.037621903)},
#  {'gene': 'MFAP3',
#   'pval': np.float64(0.947761085403238),
#   'mean_leve': np.float64(5.228990595671297),
#   'mean_grave': np.float64(5.24221380665625)},
#  {'gene': 'EYA3',
#   'pval': np.float64(0.9853848801984859),
#   'mean_leve': np.float64(4.611025046074652),
#   'mean_grave': np.float64(4.6071968528125)},
#  {'gene': 'GIMAP1',
#   'pval': np.float64(0.8132285324942073),
#   'mean_leve': np.float64(6.027559787813889),
#   'mean_grave': np.float64(5.986055106524999)},
#  {'gene': 'KLK8',
#   'pval': np.float64(0.6643389623032234),
#   'mean_leve': np.float64(2.9142139495729165),
#   'mean_grave': np.float64(2.951348084484375)},
#  {'gene': 'CCDC65',
#   'pval': np.float64(0.9297633401315848),
#   'mean_leve': np.float64(4.507281521421296),
#   'mean_grave': np.float64(4.51979474559375)},
#  {'gene': 'FAM122C',
#   'pval': np.float64(0.889766100983463),
#   'mean_leve': np.float64(3.395734533890625),
#   'mean_grave': np.float64(3.411973659132813)},
#  {'gene': 'CCDC11',
#   'pval': np.float64(0.26352518436001454),
#   'mean_leve': np.float64(2.8954075277604168),
#   'mean_grave': np.float64(2.9839654745781248)},
#  {'gene': 'ARMCX4',
#   'pval': np.float64(0.5512952883061364),
#   'mean_leve': np.float64(2.497729853777778),
#   'mean_grave': np.float64(2.45672219969375)},
#  {'gene': 'RBBP6',
#   'pval': np.float64(0.9345778168007292),
#   'mean_leve': np.float64(6.112858435688368),
#   'mean_grave': np.float64(6.120139847105468)},
#  {'gene': 'CENPBD1',
#   'pval': np.float64(0.31765020327538995),
#   'mean_leve': np.float64(4.669672651475695),
#   'mean_grave': np.float64(4.5136517403125005)},
#  {'gene': 'TRIOBP',
#   'pval': np.float64(0.8515297413495396),
#   'mean_leve': np.float64(6.855529634484721),
#   'mean_grave': np.float64(6.8740362532312504)},
#  {'gene': 'CATSPER1',
#   'pval': np.float64(0.7204358416888333),
#   'mean_leve': np.float64(3.8243003692777773),
#   'mean_grave': np.float64(3.7981456755625)},
#  {'gene': 'HOXD4',
#   'pval': np.float64(0.042631316110911956),
#   'mean_leve': np.float64(4.291920129173611),
#   'mean_grave': np.float64(4.4112352188125)},
#  {'gene': 'GSC',
#   'pval': np.float64(0.878612076960814),
#   'mean_leve': np.float64(2.3754763248055557),
#   'mean_grave': np.float64(2.38391775428125)},
#  {'gene': 'SP7',
#   'pval': np.float64(0.5586178159204533),
#   'mean_leve': np.float64(2.2381258563750004),
#   'mean_grave': np.float64(2.2040941495937503)},
#  {'gene': 'PDE7A',
#   'pval': np.float64(0.9091719560171995),
#   'mean_leve': np.float64(6.355969359352778),
#   'mean_grave': np.float64(6.3352697206875)},
#  {'gene': 'CNOT7',
#   'pval': np.float64(0.9961207403729733),
#   'mean_leve': np.float64(6.832079137949652),
#   'mean_grave': np.float64(6.833387292382812)},
#  {'gene': 'CRYZL1',
#   'pval': np.float64(0.8549584015940375),
#   'mean_leve': np.float64(5.216327427806944),
#   'mean_grave': np.float64(5.18331642145625)},
#  {'gene': 'PRSS33',
#   'pval': np.float64(0.061007936169440335),
#   'mean_leve': np.float64(6.6486110872118065),
#   'mean_grave': np.float64(6.291712445296875)},
#  {'gene': 'C19orf26',
#   'pval': np.float64(0.852216823837547),
#   'mean_leve': np.float64(3.6485187947361113),
#   'mean_grave': np.float64(3.6284773610624996)},
#  {'gene': 'C8orf45',
#   'pval': np.float64(0.905066792314325),
#   'mean_leve': np.float64(2.1118424043854165),
#   'mean_grave': np.float64(2.11666203525)},
#  {'gene': 'TIRAP',
#   'pval': np.float64(0.6776932558459702),
#   'mean_leve': np.float64(4.993709837824652),
#   'mean_grave': np.float64(4.934506053523437)},
#  {'gene': 'LEAP2',
#   'pval': np.float64(0.5359485639876471),
#   'mean_leve': np.float64(4.564851750972222),
#   'mean_grave': np.float64(4.509995976375)},
#  {'gene': 'MSI2',
#   'pval': np.float64(0.4408136439789049),
#   'mean_leve': np.float64(4.782552141938368),
#   'mean_grave': np.float64(4.691704070980469)},
#  {'gene': 'SCIN',
#   'pval': np.float64(0.953905521228953),
#   'mean_leve': np.float64(3.362528907152778),
#   'mean_grave': np.float64(3.3489769449479163)},
#  {'gene': 'CTCFL',
#   'pval': np.float64(0.312183319110918),
#   'mean_leve': np.float64(2.196336535923611),
#   'mean_grave': np.float64(2.2736979234375)},
#  {'gene': 'C4orf33',
#   'pval': np.float64(0.8929087622815425),
#   'mean_leve': np.float64(3.3048364192129633),
#   'mean_grave': np.float64(3.330762848229167)},
#  {'gene': 'ZNF333',
#   'pval': np.float64(0.8720703902534246),
#   'mean_leve': np.float64(4.897438448156249),
#   'mean_grave': np.float64(4.909114404755209)},
#  {'gene': 'FAM18B2',
#   'pval': np.float64(0.08571208171345661),
#   'mean_leve': np.float64(4.731052639423611),
#   'mean_grave': np.float64(4.624875107625)},
#  {'gene': 'RDH10',
#   'pval': np.float64(0.6582257376650493),
#   'mean_leve': np.float64(3.6631571793385422),
#   'mean_grave': np.float64(3.7255583859062504)},
#  {'gene': 'SFRS13B',
#   'pval': np.float64(0.7966786446909926),
#   'mean_leve': np.float64(2.906494607479167),
#   'mean_grave': np.float64(2.887067184140625)},
#  {'gene': 'FAM71A',
#   'pval': np.float64(0.9455776509156446),
#   'mean_leve': np.float64(4.387740443717592),
#   'mean_grave': np.float64(4.396256590385417)},
#  {'gene': 'GAPT',
#   'pval': np.float64(0.39056886762169574),
#   'mean_leve': np.float64(6.499513743368055),
#   'mean_grave': np.float64(6.59056209434375)},
#  {'gene': 'FLJ30901',
#   'pval': np.float64(0.8418080276257941),
#   'mean_leve': np.float64(4.2052773049236105),
#   'mean_grave': np.float64(4.1905422628124995)},
#  {'gene': 'C8orf47',
#   'pval': np.float64(0.46948390643083304),
#   'mean_leve': np.float64(1.7680929723958334),
#   'mean_grave': np.float64(1.73746285953125)},
#  {'gene': 'C1orf65',
#   'pval': np.float64(0.295231851983009),
#   'mean_leve': np.float64(4.814685369659723),
#   'mean_grave': np.float64(4.7733690439375)},
#  {'gene': 'ENTHD1',
#   'pval': np.float64(0.7689953901623339),
#   'mean_leve': np.float64(2.2904008904479167),
#   'mean_grave': np.float64(2.2646798188281254)},
#  {'gene': 'TSSK3',
#   'pval': np.float64(0.4775716351205631),
#   'mean_leve': np.float64(3.807250416305555),
#   'mean_grave': np.float64(3.7602379453281247)},
#  {'gene': 'WFDC6',
#   'pval': np.float64(0.2675808368936039),
#   'mean_leve': np.float64(2.9381762945069445),
#   'mean_grave': np.float64(2.875087926375)},
#  {'gene': 'CLEC12A /// CLEC12B',
#   'pval': np.float64(0.019430254295766447),
#   'mean_leve': np.float64(9.58762858057639),
#   'mean_grave': np.float64(9.99505363121875)},
#  {'gene': 'BRF1',
#   'pval': np.float64(0.8285908365616356),
#   'mean_leve': np.float64(4.3968428336493055),
#   'mean_grave': np.float64(4.377392559890625)},
#  {'gene': 'C15orf27',
#   'pval': np.float64(0.3726844752290064),
#   'mean_leve': np.float64(2.8748907523055554),
#   'mean_grave': np.float64(2.817684678875)},
#  {'gene': 'C21orf41',
#   'pval': np.float64(0.23940517833763095),
#   'mean_leve': np.float64(4.405924764701389),
#   'mean_grave': np.float64(4.343910560031249)},
#  {'gene': 'CALML6',
#   'pval': np.float64(0.9008568160305825),
#   'mean_leve': np.float64(2.7297639611458333),
#   'mean_grave': np.float64(2.72140361609375)},
#  {'gene': 'NLRP5',
#   'pval': np.float64(0.9170863944232546),
#   'mean_leve': np.float64(3.461785780465278),
#   'mean_grave': np.float64(3.46804704821875)},
#  {'gene': 'ODF4',
#   'pval': np.float64(0.4291567557957351),
#   'mean_leve': np.float64(2.9525547249826385),
#   'mean_grave': np.float64(2.904317739640625)},
#  {'gene': 'CLEC4F',
#   'pval': np.float64(0.40774723657345446),
#   'mean_leve': np.float64(4.670707096666667),
#   'mean_grave': np.float64(4.83483041534375)},
#  {'gene': 'DEFB106A /// DEFB106B',
#   'pval': np.float64(0.8034352629311983),
#   'mean_leve': np.float64(2.2726535440381945),
#   'mean_grave': np.float64(2.24868128759375)},
#  {'gene': 'WFDC9',
#   'pval': np.float64(0.90364946880086),
#   'mean_leve': np.float64(2.8111960228437503),
#   'mean_grave': np.float64(2.81846427478125)},
#  {'gene': 'NEDD1',
#   'pval': np.float64(0.820212774216147),
#   'mean_leve': np.float64(5.833448435865741),
#   'mean_grave': np.float64(5.883074338427083)},
#  {'gene': 'TTLL10',
#   'pval': np.float64(0.8811024088938286),
#   'mean_leve': np.float64(3.8378936541458333),
#   'mean_grave': np.float64(3.8449017180208336)},
#  {'gene': 'CALR3',
#   'pval': np.float64(0.7383075988844829),
#   'mean_leve': np.float64(3.389800411388889),
#   'mean_grave': np.float64(3.4112517552500004)},
#  {'gene': 'C10orf25',
#   'pval': np.float64(0.18586013783643615),
#   'mean_leve': np.float64(3.3051095316944443),
#   'mean_grave': np.float64(3.2061170814999995)},
#  {'gene': 'ETV3',
#   'pval': np.float64(0.982977316564309),
#   'mean_leve': np.float64(5.406481203724537),
#   'mean_grave': np.float64(5.402785838864584)},
#  {'gene': 'KLHL10',
#   'pval': np.float64(0.6115956796203971),
#   'mean_leve': np.float64(2.7871735503854165),
#   'mean_grave': np.float64(2.7619443725937503)},
#  {'gene': 'TM2D3',
#   'pval': np.float64(0.8021970720127688),
#   'mean_leve': np.float64(9.808999563256943),
#   'mean_grave': np.float64(9.832516421390626)},
#  {'gene': 'ZNF485',
#   'pval': np.float64(0.3814790185547111),
#   'mean_leve': np.float64(3.1505189419583335),
#   'mean_grave': np.float64(3.2034040712499996)},
#  {'gene': 'WDR17',
#   'pval': np.float64(0.7081777596732773),
#   'mean_leve': np.float64(1.894651859503472),
#   'mean_grave': np.float64(1.923596155734375)},
#  {'gene': 'MFSD6L',
#   'pval': np.float64(0.8191519906742764),
#   'mean_leve': np.float64(4.652260570375),
#   'mean_grave': np.float64(4.637244130125)},
#  {'gene': 'CDH23',
#   'pval': np.float64(0.8873809242074),
#   'mean_leve': np.float64(4.7707522986788184),
#   'mean_grave': np.float64(4.779416874492188)},
#  {'gene': 'ANKAR',
#   'pval': np.float64(0.8649277514058574),
#   'mean_leve': np.float64(2.103372853527778),
#   'mean_grave': np.float64(2.08656406496875)},
#  {'gene': 'MEGF11',
#   'pval': np.float64(0.9821830784374136),
#   'mean_leve': np.float64(3.206554445886574),
#   'mean_grave': np.float64(3.2023422339791665)},
#  {'gene': 'GPR182',
#   'pval': np.float64(0.8359046530801365),
#   'mean_leve': np.float64(3.9225054466840277),
#   'mean_grave': np.float64(3.932477241953125)},
#  {'gene': 'ESX1',
#   'pval': np.float64(0.9962259621606904),
#   'mean_leve': np.float64(1.678319919347222),
#   'mean_grave': np.float64(1.678138944125)},
#  {'gene': 'C8orf12',
#   'pval': np.float64(0.4385551063149238),
#   'mean_leve': np.float64(1.8522257162152778),
#   'mean_grave': np.float64(1.81076253884375)},
#  {'gene': 'SCGB1C1',
#   'pval': np.float64(0.21971986445975544),
#   'mean_leve': np.float64(4.043817668479167),
#   'mean_grave': np.float64(3.88227968303125)},
#  {'gene': 'DNAJC5G',
#   'pval': np.float64(0.33159463351699203),
#   'mean_leve': np.float64(2.1668210414374998),
#   'mean_grave': np.float64(2.1084253046875)},
#  {'gene': 'WDR88',
#   'pval': np.float64(0.9056391278650716),
#   'mean_leve': np.float64(2.7606266010659724),
#   'mean_grave': np.float64(2.7684223885468753)},
#  {'gene': 'PRUNE2',
#   'pval': np.float64(0.5688079004340094),
#   'mean_leve': np.float64(2.8346024156365734),
#   'mean_grave': np.float64(2.7717635945)},
#  {'gene': 'MBD3L2',
#   'pval': np.float64(0.17639934207317706),
#   'mean_leve': np.float64(3.205546909388889),
#   'mean_grave': np.float64(3.1269819511875)},
#  {'gene': 'ADAMTSL1',
#   'pval': np.float64(0.9079107007100828),
#   'mean_leve': np.float64(2.813359699246528),
#   'mean_grave': np.float64(2.8209961198072917)},
#  {'gene': 'MBD3L1',
#   'pval': np.float64(0.9283491397610182),
#   'mean_leve': np.float64(3.8121008502152782),
#   'mean_grave': np.float64(3.82061372778125)},
#  {'gene': 'FAM46D',
#   'pval': np.float64(0.2901138484293772),
#   'mean_leve': np.float64(1.955491729263889),
#   'mean_grave': np.float64(1.86582747259375)},
#  {'gene': 'SERPINB11',
#   'pval': np.float64(0.5505431761271651),
#   'mean_leve': np.float64(1.9577501124236112),
#   'mean_grave': np.float64(1.97924461140625)},
#  {'gene': 'NCRNA00161',
#   'pval': np.float64(0.2885538232471834),
#   'mean_leve': np.float64(2.0435406286388886),
#   'mean_grave': np.float64(2.09137635809375)},
#  {'gene': 'DSCR10',
#   'pval': np.float64(0.8096983817733351),
#   'mean_leve': np.float64(3.4620389562291667),
#   'mean_grave': np.float64(3.4745144992812502)},
#  {'gene': 'ABHD11',
#   'pval': np.float64(0.6334179567136871),
#   'mean_leve': np.float64(4.692690398872685),
#   'mean_grave': np.float64(4.62093313978125)},
#  {'gene': 'ACAP2',
#   'pval': np.float64(0.19276728194301546),
#   'mean_leve': np.float64(8.686676895739584),
#   'mean_grave': np.float64(8.802636951937501)},
#  {'gene': 'GAMT',
#   'pval': np.float64(0.9528390375128943),
#   'mean_leve': np.float64(3.4198549819305555),
#   'mean_grave': np.float64(3.4175286324062504)},
#  {'gene': 'PLCD3',
#   'pval': np.float64(0.9684400952946639),
#   'mean_leve': np.float64(4.349864958298612),
#   'mean_grave': np.float64(4.3359742595781245)},
#  {'gene': 'IRF6',
#   'pval': np.float64(0.8795488348027011),
#   'mean_leve': np.float64(3.066732486935185),
#   'mean_grave': np.float64(3.0810289184270836)},
#  {'gene': 'PTPRC',
#   'pval': np.float64(0.7731304589125025),
#   'mean_leve': np.float64(8.713430932122222),
#   'mean_grave': np.float64(8.76982284215625)},
#  {'gene': 'MAN1A2',
#   'pval': np.float64(0.8928346203927795),
#   'mean_leve': np.float64(4.094264618806944),
#   'mean_grave': np.float64(4.07556649269375)},
#  {'gene': 'RAPH1',
#   'pval': np.float64(0.7367695091428673),
#   'mean_leve': np.float64(4.1092904252625),
#   'mean_grave': np.float64(4.1633105833125)},
#  {'gene': 'SMCR8',
#   'pval': np.float64(0.9376939944944214),
#   'mean_leve': np.float64(5.419749808238889),
#   'mean_grave': np.float64(5.43397508733125)},
#  {'gene': 'LACTB',
#   'pval': np.float64(0.6774044112993007),
#   'mean_leve': np.float64(5.188734717905094),
#   'mean_grave': np.float64(5.250601477208334)},
#  {'gene': 'BNC1',
#   'pval': np.float64(0.9280758322672268),
#   'mean_leve': np.float64(1.4190469941909722),
#   'mean_grave': np.float64(1.4156243855625)},
#  {'gene': 'MPP4',
#   'pval': np.float64(0.41064019419029607),
#   'mean_leve': np.float64(2.045786517826389),
#   'mean_grave': np.float64(2.07775638859375)},
#  {'gene': 'LACE1',
#   'pval': np.float64(0.67539005099709),
#   'mean_leve': np.float64(1.989389947295139),
#   'mean_grave': np.float64(2.011638705359375)},
#  {'gene': 'IDI2',
#   'pval': np.float64(0.3889120164689085),
#   'mean_leve': np.float64(5.606372586302083),
#   'mean_grave': np.float64(5.5426359168124995)},
#  {'gene': 'CYP11B1',
#   'pval': np.float64(0.851410136311382),
#   'mean_leve': np.float64(3.111657595364583),
#   'mean_grave': np.float64(3.0821205043593753)},
#  {'gene': 'TAF8',
#   'pval': np.float64(0.7227739496996628),
#   'mean_leve': np.float64(5.023208674080555),
#   'mean_grave': np.float64(4.982341173575)},
#  {'gene': 'COBL',
#   'pval': np.float64(0.6289451302995865),
#   'mean_leve': np.float64(2.6063511338506946),
#   'mean_grave': np.float64(2.62531507865625)},
#  {'gene': 'SLAMF6',
#   'pval': np.float64(0.4172229415116322),
#   'mean_leve': np.float64(7.286619329305555),
#   'mean_grave': np.float64(7.38142137096875)},
#  {'gene': 'ZSCAN20',
#   'pval': np.float64(0.5164638931388066),
#   'mean_leve': np.float64(2.7198089137199073),
#   'mean_grave': np.float64(2.68183895196875)},
#  {'gene': 'GPBAR1',
#   'pval': np.float64(0.9972806576311214),
#   'mean_leve': np.float64(6.5548562301805555),
#   'mean_grave': np.float64(6.55444196365625)},
#  {'gene': 'RHBDL2',
#   'pval': np.float64(0.9318299682409064),
#   'mean_leve': np.float64(4.2224871712314815),
#   'mean_grave': np.float64(4.237150294145834)},
#  {'gene': 'FRAS1',
#   'pval': np.float64(0.6156195041958483),
#   'mean_leve': np.float64(2.580603878342593),
#   'mean_grave': np.float64(2.606769868609375)},
#  {'gene': 'BRSK1',
#   'pval': np.float64(0.21319172678400958),
#   'mean_leve': np.float64(4.3163102465902785),
#   'mean_grave': np.float64(4.22816874815625)},
#  {'gene': 'CRB2',
#   'pval': np.float64(0.9822609794563353),
#   'mean_leve': np.float64(3.9520058395069446),
#   'mean_grave': np.float64(3.9508596031875003)},
#  {'gene': 'KCNE4',
#   'pval': np.float64(0.3932209802232859),
#   'mean_leve': np.float64(1.9677926599953703),
#   'mean_grave': np.float64(1.9346882305833333)},
#  {'gene': 'CD300LG',
#   'pval': np.float64(0.9926665463445417),
#   'mean_leve': np.float64(2.693114242151042),
#   'mean_grave': np.float64(2.694182473585937)},
#  {'gene': 'SLC34A3',
#   'pval': np.float64(0.9353557115466755),
#   'mean_leve': np.float64(3.6896834635833335),
#   'mean_grave': np.float64(3.6974115341406253)},
#  {'gene': 'CPA6',
#   'pval': np.float64(0.5159065505098619),
#   'mean_leve': np.float64(2.0914794848333336),
#   'mean_grave': np.float64(2.0669050398906252)},
#  {'gene': 'WBP2NL',
#   'pval': np.float64(0.13420024853234347),
#   'mean_leve': np.float64(2.3179160341736114),
#   'mean_grave': np.float64(2.43812228309375)},
#  {'gene': 'HIPK1',
#   'pval': np.float64(0.9427701924092062),
#   'mean_leve': np.float64(5.276541958673611),
#   'mean_grave': np.float64(5.296666405804688)},
#  {'gene': 'MTBP',
#   'pval': np.float64(0.859152198696393),
#   'mean_leve': np.float64(2.21081870246875),
#   'mean_grave': np.float64(2.1999048115859376)},
#  {'gene': 'ACVR1C',
#   'pval': np.float64(0.3672334870886458),
#   'mean_leve': np.float64(2.770795872795139),
#   'mean_grave': np.float64(2.84481715603125)},
#  {'gene': 'TMEM74',
#   'pval': np.float64(0.9499492395044307),
#   'mean_leve': np.float64(2.529139828453704),
#   'mean_grave': np.float64(2.5226157046354167)},
#  {'gene': 'TIGD4',
#   'pval': np.float64(0.7734591786598297),
#   'mean_leve': np.float64(2.2931308837500004),
#   'mean_grave': np.float64(2.279787927359375)}]

# %%
import plotly.graph_objects as go

# Adiciona coluna para -log10(pval)
res_df['-log10_pval'] = -np.log10(res_df['pval'])

# Define cores: destaque genes significativos
colors = np.where((res_df['pval'] < 0.05) & (abs(res_df['log2fc']) > 1), '#A259C6', '#4CB944')

fig = go.Figure()

fig.add_trace(go.Scatter(
    x=res_df['log2fc'],
    y=res_df['-log10_pval'],
    mode='markers',
    marker=dict(
        color=colors,
        size=8,
        line=dict(width=0.5, color='DarkSlateGrey')
    ),
    text=res_df['gene'],  # hover com nome do gene
    hovertemplate='Gene: %{text}<br>log2FC: %{x:.2f}<br>-log10(pval): %{y:.2f}<extra></extra>'
))

fig.update_layout(
    title='Volcano Plot - Expressão Diferencial',
    xaxis_title='log2 Fold Change',
    yaxis_title='-log10(p-valor)',
    template='plotly_white',
    width=700,
    height=500
)

fig.show()

# %%
# Visualizacoes uteis

# gse = GEOparse.get_GEO(geo="GSE121239", destdir="../../data/raw/", silent=True)
# gse.gsms['GSM3428621'].metadata # Metadados pacientes
# gse.gsms['GSM3428621'].table # Tabela de genes
# gpl.head() # De para de Genes
# Out:
# {'title': ['PBMC_SLE2132_v4'],
#  'geo_accession': ['GSM3428621'],
#  'status': ['Public on Oct 15 2018'],
#  'submission_date': ['Oct 15 2018'],
#  'last_update_date': ['Oct 15 2018'],
#  'type': ['RNA'],
#  'channel_count': ['1'],
#  'source_name_ch1': ['PBMC_SLE2132_v4'],
#  'organism_ch1': ['Homo sapiens'],
#  'taxid_ch1': ['9606'],
#  'characteristics_ch1': ['disease state: Systemic Lupus Erythematosus',
#   'patient id: 2132',
#   'sledai: 2',
#   'visit date: 2010-12-15',
#   'tissue: PBMC',
#   'imputed neutrophil percentage: 56.2'],
#  'treatment_protocol_ch1': ['Standard.'],
#  'growth_protocol_ch1': ['Whole Blood samples in collected fom PAXgene tubes.'],
#  'molecule_ch1': ['total RNA'],
#  'extract_protocol_ch1': ['The RNA was extracted with Trizol reagent (Life Technologies) and cleaned up with RNA easy (Qiagen) according to the manufacturer’s protocols.'],
#  'label_ch1': ['Biotin'],
#  'label_protocol_ch1': ['NuGEN Ovation.'],
#  'hyb_protocol': ['Standard Affymetrix protcol.'],
#  'scan_protocol': ['HTAPS scan was used.'],
#  'description': ['Gene expression microarray from a patient in a visit'],
#  'data_processing': ['Data was normalized using rma R package.'],
#  'platform_id': ['GPL13158'],
#  'contact_name': ['Daniel,,Toro'],
#  'contact_email': ['danieltorodominguez@gmail.com'],
#  'contact_department': ['Bioinformatics'],
#  'contact_institute': ['GENYO'],
#  'contact_address': ['Avenida de la Ilustracion'],
#  'contact_city': ['GRANADA'],
#  'contact_state': ['Spain'],
#  'contact_zip/postal_code': ['18016'],
#  'contact_country': ['Spain'],
#  'supplementary_file': ['ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3428nnn/GSM3428621/suppl/GSM3428621_101613_119686173_169.CEL.gz'],
#  'series_id': ['GSE121239'],
#  'data_row_count': ['54715']}
